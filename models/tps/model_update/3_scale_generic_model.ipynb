# %% [markdown]
# # Imports

# %%
import opensim as osim
import os
from simFunctions import runProgram, scaleOptimalForceSubjectSpecific
# from stan_utils import subject_specific_isometric_force
import pandas as pd
os.getcwd()
# Out:
# 'c:\\Git\\powerlifing_model_clean\\models\\tps\\model_update'

# %% [markdown]
# ### +++ static +++

# %% [markdown]
# # Udate Scaling XML
#
# This file uses scaling scheme that is already given in scaling_setting.xml.
#
# For walking, the model is scaled following distances between external markers and muscle forces are scaled by a factor calculated with mass and height of the subject relative the mass and the height of the generic model.

# %%
from paths_setup import *
print(experimental_markers)
# Out:
# Created directory: c:\Git\powerlifing_model_clean\models\tps\final_results\personalized
# c:\Git\powerlifing_model_clean\models\tps\motion_lab/static/static_01/task.trc

# %%
static_df = pd.read_csv(experimental_markers, delimiter='\t', skiprows=3, header=[0,1], index_col=0)
# <time_range>'
time_range = f' 0 {list(static_df.loc[static_df.shape[0], "Time"])[0] }'

# %%
import xml.etree.ElementTree as ET

# parse the .xml with markers in body frames
scaling_tree=ET.parse(scaling_settings_path)
scaling_root = scaling_tree.getroot()
model = osim.Model(path_to_generic_model)  # Load the generic model

# %%
import xml.etree.ElementTree as ET

# parse the .xml with markers in body frames
scaling_tree=ET.parse(scaling_settings_path)
scaling_root = scaling_tree.getroot()

for scaleTool in scaling_root.iter('ScaleTool'):
    scaleTool.set('name',model.getName())

for generic_model in scaling_root.iter('model_file'):
    generic_model.text = path_to_generic_model

for generic_marker_set in scaling_root.iter('marker_set_file'):
    generic_marker_set.text = path_to_generic_marker_set

for exp_markers in scaling_root.iter('marker_file'):
    exp_markers.text = experimental_markers

for time in scaling_root.iter('time_range'):
    time.text = time_range

for output in scaling_root.iter('output_model_file'):
    output.text = output_model_file

for scale in scaling_root.iter('output_scale_file'):
    scale.text = output_scale_file

for generic_marker_set in scaling_root.iter('marker_set_file'):
    generic_marker_set.text = path_to_generic_marker_set

for exp_markers in scaling_root.iter('marker_file'):
    exp_markers.text = experimental_markers

for time in scaling_root.iter('time_range'):
    time.text = time_range

for output in scaling_root.iter('output_model_file'):
    output.text = output_model_file

for scale in scaling_root.iter('output_scale_file'):
    scale.text = output_scale_file

for marker_placer in scaling_root.iter('MarkerPlacer'):
    apply = marker_placer.find('apply')
    apply.text = 'true'

# %%
for mass in scaling_root.iter('mass'):
	mass.text = mass_text

for height in scaling_root.iter('height'):
	height.text = height_text

for age in scaling_root.iter('age'):
	age.text = age_text

# %%
scaling_tree.write(output_scaling_settings)
print(f"Written scaling settings to: {output_scaling_settings}")
# Out:
# Written scaling settings to: c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\scaling_setting.xml

# %% [markdown]
# ## 2.1 Scale model to markers

# %%
cmdprog = 'opensim-cmd'
cmdtool = 'run-tool'
cmdfile = output_scaling_settings
cmdfull = [cmdprog, cmdtool, cmdfile]
rc = runProgram(cmdfull)
# Out:
# c:\Users\Bas\miniconda3\envs\py311\Lib\subprocess.py:1016: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [info] Preparing to run ScaleTool.
#
# [info] Processing subject Catelli_high_hip_flexion_V4.0...
#
# [info] Step 1: Loading generic model
#
# [info] Loaded model Catelli_high_hip_flexion_V4.0 from file c:\Git\1_current_projects\powerlifing_model\models\athlete_03\templates\Catelli-V4.0.osim
#
# [info] Loading marker set from 'c:\Git\1_current_projects\powerlifing_model\models\athlete_03\templates/generic_skin_markers.xml'.
#
# [info] Updated markers in model Catelli_high_hip_flexion_V4.0
#
# [info] Step 2: Scaling generic model
#
# [info] Loaded marker file c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc (73 markers, 693 frames)
#
# [info] Measurement 'pelvis width'
#
# [info] 	pair 0 (LASI, RASI): model = 0.256, experimental = 0.227666
#
# [info] 	pair 1 (LPSI, RPSI): model = 0.0759902, experimental = 0.0891936
#
# [info] 	overall scale factor = 1.03154
#
# [info] Measurement 'pelvis height'
#
# [warning] Marker LMKNE in pelvis height measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker LMKNE in pelvis height measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'pelvis height' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'torso height'
#
# [warning] Marker PE01 in torso height measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker PE01 in torso height measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'torso height' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'torso depth'
#
# [warning] Marker T10 in torso depth measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker T10 in torso depth measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'torso depth' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'femur_r_length'
#
# [warning] Marker RMKNE in femur_r_length measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker RMKNE in femur_r_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'femur_r_length' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'femur_l_length'
#
# [warning] Marker LMKNE in femur_l_length measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker LMKNE in femur_l_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'femur_l_length' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'tibia_r_length'
#
# [warning] Marker RKNE in tibia_r_length measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker RKNE in tibia_r_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] Marker RANK in tibia_r_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'tibia_r_length' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'tibia_l_length'
#
# [warning] Marker LKNE in tibia_l_length measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker LKNE in tibia_l_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] Marker LANK in tibia_l_length measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'tibia_l_length' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'foot_horiz_l'
#
# [info] 	pair 0 (LHEE, LTOE): model = 0.209945, experimental = 0.212017
#
# [info] 	overall scale factor = 1.00987
#
# [info] Measurement 'foot_horiz_r'
#
# [info] 	pair 0 (RHEE, RTOE): model = 0.209945, experimental = 0.211009
#
# [info] 	overall scale factor = 1.00507
#
# [info] Measurement 'foot_vertic_l'
#
# [warning] Marker LANK in foot_vertic_l measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker LANK in foot_vertic_l measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'foot_vertic_l' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Measurement 'foot_vertic_r'
#
# [warning] Marker RANK in foot_vertic_r measurement not found in Catelli_high_hip_flexion_V4.0.
#
# [warning] Marker RANK in foot_vertic_r measurement not found in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc.
#
# [warning] 'foot_vertic_r' measurement not used to scale Catelli_high_hip_flexion_V4.0
#
# [info] Wrote model file 'c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\scaled_model.osim' from model.
#
# [info] Wrote scale file 'c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\output_scale_file.txt' for model Catelli_high_hip_flexion_V4.0.
#
# [info] Step 3: Placing markers on model
#
# [info] Loaded marker file c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc (73 markers, 693 frames)
#
# [info] Averaged frames from time 0.0 to 3.46 in c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc (frames 1 to 693)
#
# [info] Deleted 6 unused markers from model Catelli_high_hip_flexion_V4.0.
#
# [info] Frame at (t = 0.0):	 total squared error = 0.00356615, marker error: RMS = 0.0119435, max = 0.0322678 (RASI)
#
# [info] Moved markers in model Catelli_high_hip_flexion_V4.0 to match locations in marker file 'c:\Git\1_current_projects\powerlifing_model\models\athlete_03\motion_lab/static/static_01/task.trc'.
#
# [info] Wrote model file 'c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\scaled_model.osim' from model Catelli_high_hip_flexion_V4.0.
#
#
# Return code:  None

# %% [markdown]
# ## Scale model muscle forces to height and weight

# %%
generic_model = osim.Model(path_to_generic_model)
model=osim.Model(output_model_file)
scaled = scaleOptimalForceSubjectSpecific(generic_model, model, 1.77, float(height_text))

# %% [markdown]
# # Set <ignore_tendon_compliance> and <ignore_activation_dynamics> to true

# %%
muscle_set = scaled.getMuscles()
for i in range(muscle_set.getSize()):
    current = muscle_set.get(i)
    current.set_ignore_activation_dynamics(True)
    current.set_ignore_tendon_compliance(True)

# %% [markdown]
# ## Increase Pelvis Tilt

# %%
# pelvis_coordinates = model.getCoordinateSet().get('pelvis_tilt')
# pelvis_coordinates.setRangeMax(4)
# pelvis_coordinates.setRangeMin(-4)

# %% [markdown]
# ## Save the model

# %%
scaled.printToXML(output_model_file)
model = osim.Model(output_model_file)  # Reload the model to update it
model.setName(f'{model.getName()}_scaled')
model.printToXML(os.path.join(path_to_model, f'scaled_model.osim'))
print(f"Model with updated joint locations saved to: \n {os.path.join(path_to_model, f'scaled_model.osim')}")
# Out:
# Model with updated joint locations saved to:
#  c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\scaled_model.osim

# %% [markdown]
# ## Scale muscle fibres

# %%
# from fibre_scale_script import *
# # define models
# generic_model = '../templates/RajagopalModified_generic_copy.osim'
# model_to_update = output_model_file
# updated_model = output_model_file

# # run scripts
# osimModel_opt, SimInfo = optimMuscleParams(generic_model, model_to_update, 2, '3a_osim_markers/logging')

# # printing the optimized model
# osimModel_opt.printToXML(updated_model)

# %% [markdown]
# # Add joint center markers and save another model

# %%
model = osim.Model(output_model_file)
for body in model.getBodySet():
    if body.getName() == 'torso':
        torso_body = body

    if body.getName() == 'pelvis':
        pelvis_body = body
    if body.getName() == 'femur_r':
        femur_r_body = body
    if body.getName() == 'femur_l':
        femur_l_body = body

    if body.getName() == 'patella_r':
        patella_r_body = body
    if body.getName() == 'patella_l':
        patella_l_body = body

    if body.getName() == 'tibia_r':
        tibia_r_body = body
    if body.getName() == 'tibia_l':
        tibia_l_body = body

    if body.getName() == 'talus_r':
        talus_r_body = body
    if body.getName() == 'talus_l':
        talus_l_body = body

# %%
torso_m = osim.Marker("torso_origin_in_pelvis", torso_body, osim.Vec3(0,0,0))
femur_l_m = osim.Marker("femur_l_center_in_pelvis", femur_l_body, osim.Vec3(0,0,0))
femur_r_m = osim.Marker("femur_r_center_in_pelvis", femur_r_body, osim.Vec3(0,0,0))
patella_l_m = osim.Marker("patella_l_in_femur_l", patella_l_body, osim.Vec3(0,0,0))
patella_r_m = osim.Marker("patella_r_in_femur_r", patella_r_body, osim.Vec3(0,0,0))
tibia_l_m = osim.Marker("knee_l_center_in_femur_l", tibia_l_body, osim.Vec3(0,0,0))
tibia_r_m = osim.Marker("knee_r_center_in_femur_r", tibia_r_body, osim.Vec3(0,0,0))
talus_l_m = osim.Marker("talus_l_center_in_tibia", talus_l_body, osim.Vec3(0,0,0))
talus_r_m = osim.Marker("talus_r_center_in_tibia", talus_r_body, osim.Vec3(0,0,0))

model.addMarker(torso_m)
model.addMarker(femur_l_m)
model.addMarker(femur_r_m)
model.addMarker(patella_l_m)
model.addMarker(patella_r_m)
model.addMarker(tibia_l_m)
model.addMarker(tibia_r_m)
model.addMarker(talus_l_m)
model.addMarker(talus_r_m)

model.finalizeConnections()

# %%
state = model.initSystem()

torso_m.changeFramePreserveLocation(state, pelvis_body)
femur_l_m.changeFramePreserveLocation(state, pelvis_body)
femur_r_m.changeFramePreserveLocation(state, pelvis_body)
patella_l_m.changeFramePreserveLocation(state, femur_l_body)
patella_r_m.changeFramePreserveLocation(state, femur_r_body)
tibia_l_m.changeFramePreserveLocation(state, femur_l_body)
tibia_r_m.changeFramePreserveLocation(state, femur_r_body)
talus_l_m.changeFramePreserveLocation(state, tibia_l_body)
talus_r_m.changeFramePreserveLocation(state, tibia_r_body)

# %%
model.finalizeConnections()
model.setName(f'{model.getName()}_scaled_joints_updated')
model.printToXML(os.path.join(path_to_model, f'scaled_model_joints.osim'))
print(f"Model with updated joint locations saved to: \n {os.path.join(path_to_model, f'scaled_model_joints.osim')}")
# Out:
# Model with updated joint locations saved to:
#  c:\Git\1_current_projects\powerlifing_model\models\athlete_03\final_results\generic_scaled\scaled_model_joints.osim
